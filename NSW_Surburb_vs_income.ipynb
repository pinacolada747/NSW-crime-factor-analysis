# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
# %matplotlib inline

# %%
df = pd.read_csv('Suburb_vs_Income4.csv')

# %%
df1 = pd.read_csv('Suburb_vs_Income4.csv')

# %%
df1.tail(50)
# Out:
#                            Household income      0    100    150     200  \
# 2579                                Wyalong      3      6      3      19
# 2580                               Wyangala      0      6      7       7
# 2581                                 Wybung      0      0      0       0
# 2582                                   Wyee      8     11     18      66
# 2583                             Wyee Point      3      6      3       4
# 2584                          Wyndham (NSW)      0      3     13      23
# 2585                                Wyoming     28     56    113     367
# 2586                                  Wyong     12     38     95     195
# 2587                            Wyong Creek      0      3      0       7
# 2588                                Wyongah      6      4     11      41
# 2589                               Wyrallah      0      0      3       8
# 2590                                Yagoona     65    104    169     389
# ...

# %%
dummy_list = []
for i in range(2629):
    a = random.randint(0,323)
    dummy_list.append(a)

# %%
df['dummylist'] = dummy_list

# %%
dummy_dict = {}
for i in df.columns:
    alpha = 99999
    dummy_dict[i] = alpha
dummy_dict
# Out:
# {'Household income': 99999,
#  '0': 99999,
#  '100': 99999,
#  '150': 99999,
#  '200': 99999,
#  '500': 99999,
#  '700': 99999,
#  '900': 99999,
#  '1125': 99999,
#  '1375': 99999,
#  '1750': 99999,
#  '2250': 99999,
#  '2750': 99999,
#  '3250': 99999,
#  '3750': 99999,
#  '4500': 99999,
#  '7500': 99999,
#  'dummylist': 99999}

# %%
df.head()
# Out:
#    Household income   0  100  150  200  500  700  900  1125  1375  1750  2250  \
# 0        Abbotsbury  10   12   16   11   47   61   59    73    88   142   148
# 1  Abbotsford (NSW)  30   29   64  131  152  110  102   135   113   201   153
# 2       Abercrombie   3    0    4   10   19   20   22    16    17    40    40
# 3          Aberdare  11   17   24   84  113  104   82    81    64    94    53
# 4    Aberdeen (NSW)   3   10   11   57   78   70   49    56    63   105    58
#
#    2750  3250  3750  4500  7500  dummylist
# 0   130    84    58    46    42        298
# 1   260   136    94    91   124        275
# 2    37    29    11     4     4        248
# 3    46    29     9     0     3        249
# 4    92    50    10    12     7         26

# %%
df = df.append(dummy_dict, ignore_index = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1856\3995867949.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dummy_dict, ignore_index = True)

# %%
df.drop(df.index[2629:2630], inplace = True)

# %%
df.tail()
# Out:
#      Household income      0    100    150    200    500    700    900   1125  \
# 2634            99999  99999  99999  99999  99999  99999  99999  99999  99999
# 2635            99999  99999  99999  99999  99999  99999  99999  99999  99999
# 2636            99999  99999  99999  99999  99999  99999  99999  99999  99999
# 2637            99999  99999  99999  99999  99999  99999  99999  99999  99999
# 2638            99999  99999  99999  99999  99999  99999  99999  99999  99999
#
#        1375   1750   2250   2750   3250   3750   4500   7500  dummylist
# 2634  99999  99999  99999  99999  99999  99999  99999  99999      99999
# 2635  99999  99999  99999  99999  99999  99999  99999  99999      99999
# 2636  99999  99999  99999  99999  99999  99999  99999  99999      99999
# 2637  99999  99999  99999  99999  99999  99999  99999  99999      99999
# 2638  99999  99999  99999  99999  99999  99999  99999  99999      99999

# %%
df.drop(df.index[2630:], inplace = False)
# Out:
#                            Household income      0    100    150     200  \
# 0                                Abbotsbury     10     12     16      11
# 1                          Abbotsford (NSW)     30     29     64     131
# 2                               Abercrombie      3      0      4      10
# 3                                  Aberdare     11     17     24      84
# 4                            Aberdeen (NSW)      3     10     11      57
# ...                                     ...    ...    ...    ...     ...
# 2625                                Zetland     98     24     29      35
# 2626                     Unclassified (NSW)      0      0      0       0
# 2627  Migratory - Offshore - Shipping (NSW)      0      0      0       0
# 2628                                 ?????  27892  39699  71929  161505
# 2629                                  99999  99999  99999  99999   99999
#
#          500     700     900    1125    1375    1750    2250    2750    3250  \
# ...

# %%
df = df.drop(df.index[2628:], inplace = False)

# %%
df.tail()
# Out:
#                            Household income   0  100  150  200  500  700  900  \
# 2623                              Yowie Bay  12    3    5   30   64   68   80
# 2624                               Yuraygir   0    0    0    0    0    3    0
# 2625                                Zetland  98   24   29   35   60   65   87
# 2626                     Unclassified (NSW)   0    0    0    0    0    0    0
# 2627  Migratory - Offshore - Shipping (NSW)   0    0    0    0    0    0    0
#
#       1125  1375  1750  2250  2750  3250  3750  4500  7500  dummylist
# 2623    52    43   100    83   107   104    53    58    55        235
# 2624     0     0     0     0     0     0     0     0     0        176
# 2625    95   115   205   141   225   130    78    66    60         86
# 2626     0     0     0     0     0     0     0     0     0        180
# 2627     0     0     0     0     0     0     0     0     0         98

# %%
df = df.drop(['dummylist'],axis = 1)

# %%
df.columns
# Out:
# Index(['Household income', '0', '100', '150', '200', '500', '700', '900',
#        '1125', '1375', '1750', '2250', '2750', '3250', '3750', '4500', '7500',
#        'population'],
#       dtype='object')

# %%
df['population'] = df.mean(axis=1) # df[new_col_name] = new series 
print(df['population'])
# Out:
# 324      6.438632
# 325     16.769794
# 326      4.956646
# 327      6.782210
# 328     61.463057
#           ...
# 2623    57.348667
# 2624     0.223285
# 2625    94.560757
# 2626     0.036637
# 2627     0.019947
# Name: population, Length: 2304, dtype: float64
# C:\Users\user\AppData\Local\Temp\ipykernel_1856\3038368275.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['population'] = df.mean(axis=1) # df[new_col_name] = new series

# %%
print(list(df.columns))[1:-1]
# Out:
# ['Household income', '0', '100', '150', '200', '500', '700', '900', '1125', '1375', '1750', '2250', '2750', '3250', '3750', '4500', '7500', 'population']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [112], in <cell line: 1>()
# ----> 1 print(list(df.columns))[1:-1]
#
# TypeError: 'NoneType' object is not subscriptable
